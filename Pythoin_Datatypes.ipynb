# %% [markdown]
# <a href="https://colab.research.google.com/github/hegdeseema20/Python_2026_learning_DE/blob/feature_branch_python_datatypes/Pythoin_Datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================================
# 📚 PYTHON DATA TYPES & COLLECTIONS
# ==========================================

# ==========================================
# 1. INTEGER (int)
# ==========================================
age = 35

print("=== Integer (int) ===")
print("Age:", age)
print("Adding five years to age:", age + 5)
print("Double the age:", age * 2)


# ==========================================
# 2. FLOAT (float)
# ==========================================
height = 5.9
weight = 70.5

print("\n=== Float (float) ===")
print("Height after adding 1.1:", height + 1.1)
print("Weight divided by 2:", weight / 2)
print("Height multiplied by 2:", height * 2)


# ==========================================
# 3. STRING (str)
# ==========================================
name = "alice"
city = "vancouver"

print("\n=== String (str) ===")
print("Name capitalized:", name.capitalize())
print("City in uppercase:", city.upper())
print("Concatenated string:", name + " lives here")
print("Number of letters in city:", len(city))


# ==========================================
# 4. BOOLEAN (bool)
# ==========================================
is_student = True
is_adult = False

print("\n=== Boolean (bool) ===")
print("AND:", is_student and is_adult)
print("OR:", is_student or is_adult)
print("NOT:", not is_student)
print("Age < 30?:", age < 30)


# ==========================================
# 5. LIST (list)
# ==========================================
fruits = ["Apple", "Banana", "Cherry"]

print("\n=== List ===")
print("Original:", fruits)

# Add
fruits.append("Orange")
print("After append:", fruits)

# Modify
fruits[1] = "Blueberry"
print("After modify:", fruits)

# Remove
fruits.remove("Cherry")
print("After remove:", fruits)

# Insert
fruits.insert(2, "Dragon Fruit")
print("After insert:", fruits)

# Pop
fruits.pop()
print("After pop:", fruits)

# Extend
fruits.extend(["Mango", "Watermelon"])
print("After extend:", fruits)

# Delete slice
del fruits[1:3]
print("After delete slice:", fruits)

# Add more for sorting
fruits.extend(["lemon", "dates", "lemon", "grapes"])
print("Before sorting:", fruits)

# Sort
fruits.sort()
print("Sorted:", fruits)

# Reverse sort
fruits.sort(reverse=True)
print("Reverse sorted:", fruits)

# Sort by length
fruits.sort(key=len)
print("Sort by length:", fruits)

# Clear
fruits.clear()
print("After clear:", fruits)


# ==========================================
# 6. TUPLE (tuple)
# ==========================================
point = (10, 20, 20)

print("\n=== Tuple ===")
print("Tuple:", point)
print("Access element:", point[1])
print("Count of 20:", point.count(20))

# Immutable (cannot change)
# point[1] = 10  # ❌ This will cause an error


# ==========================================
# 7. SET (set)
# ==========================================
numbers = {1, 6, 3, 8, 2, 7, 2}

print("\n=== Set ===")
print("Original (duplicates removed):", numbers)

numbers.add(9)
print("After adding:", numbers)


# ==========================================
# 8. DICTIONARY (dict)
# ==========================================
student = {
    "name": "Alex",
    "age": 16,
    "grade": "A"
}

print("\n=== Dictionary ===")
print("Original:", student)

# Modify
student["age"] = 20
print("After updating age:", student)

# Add new key
student["address"] = "King George Blvd"
print("After adding address:", student)


# ==========================================
# 🧠 QUICK MEMORY GUIDE
# ==========================================
print("\n=== Memory Guide ===")
print("List      → 🛒 Shopping list (ordered, changeable)")
print("Tuple     → 📍 GPS coordinates (ordered, fixed)")
print("Set       → 🎟️ Unique items (no duplicates)")
print("Dictionary → 📇 Contact book (key-value pairs)")
# Out:
# === Integer (int) ===
# Age: 35
# Adding five years to age: 40
# Double the age: 70
#
# === Float (float) ===
# Height after adding 1.1: 7.0
# Weight divided by 2: 35.25
# Height multiplied by 2: 11.8
#
# === String (str) ===
# Name capitalized: Alice
# City in uppercase: VANCOUVER
# Concatenated string: alice lives here
# Number of letters in city: 9
#
# === Boolean (bool) ===
# AND: False
# OR: True
# NOT: False
# Age < 30?: False
#
# === List ===
# Original: ['Apple', 'Banana', 'Cherry']
# After append: ['Apple', 'Banana', 'Cherry', 'Orange']
# After modify: ['Apple', 'Blueberry', 'Cherry', 'Orange']
# After remove: ['Apple', 'Blueberry', 'Orange']
# After insert: ['Apple', 'Blueberry', 'Dragon Fruit', 'Orange']
# After pop: ['Apple', 'Blueberry', 'Dragon Fruit']
# After extend: ['Apple', 'Blueberry', 'Dragon Fruit', 'Mango', 'Watermelon']
# After delete slice: ['Apple', 'Mango', 'Watermelon']
# Before sorting: ['Apple', 'Mango', 'Watermelon', 'lemon', 'dates', 'lemon', 'grapes']
# ...
